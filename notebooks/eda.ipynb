# %%
import pandas as pd
import numpy as np
import sweetviz as sv

# %%
sample1 = pd.read_csv('../data/sample/sample-analysis-1.csv')
sample2 = pd.read_csv('../data/sample/sample-analysis-2.csv')
sample3 = pd.read_csv('../data/sample/sample-analysis-3.csv')

# %%
sample1
# Out:
#       DESIRED  Business Acumen  Interpersonal Sensitivity  \
# 0  Employee A                2                          2
# 1  Employee B                3                          3
#
#    Problem Solving and Decision Making  Communication Skills  \
# 0                                    3                     3
# 1                                    3                     1
#
#    Corporate Steward  Relevant Professional Understanding  \
# 0                3.0                                    4
# 1                NaN                                    2
#
#    Proficiency in the use of System and Tools  Data Management  \
# 0                                           2                2
# 1                                           2                2
#
#    People Development  Strategic Management
# 0                   1                     2
# 1                   3                     3

# %%
sample2
# Out:
#   SUP ASSESSMENT  Business Acumen  Interpersonal Sensitivity  \
# 0     Employee A                3                          3
# 1     Employee B                4                          4
#
#    Problem Solving and Decision Making  Communication Skills  \
# 0                                    3                     3
# 1                                    4                     4
#
#    Corporate Steward  Relevant Professional Understanding  \
# 0                  3                                    3
# 1                  3                                    3
#
#    Proficiency in the use of System and Tools  Data Management  \
# 0                                           2                2
# 1                                           3                3
#
#    People Development  Strategic Management
# 0                   2                     2
# 1                   2                     2

# %%
sample3
# Out:
#      COMPARED Business Acumen Interpersonal Sensitivity  \
# 0  Employee A       Exceeding                 Exceeding
# 1  Employee B       Exceeding                 Exceeding
#
#   Problem Solving and Decision Making Communication Skills Corporate Steward  \
# 0                          Exhibiting           Exhibiting        Exhibiting
# 1                           Exceeding            Exceeding         No Rating
#
#   Relevant Professional Understanding  \
# 0                  Below Expectations
# 1                           Exceeding
#
#   Proficiency in the use of System and Tools Data Management  \
# 0                                 Exhibiting      Exhibiting
# 1                                  Exceeding       Exceeding
#
#    People Development Strategic Management
# 0           Exceeding           Exhibiting
# 1  Below Expectations   Below Expectations

# %%
competencies = pd.read_csv('../data/raw/Desired Competencies.csv')
auto = pd.read_csv('../data/raw/Self Assessment SURVEY Result.csv')
sup = pd.read_csv('../data/raw/Sup Assessment SURVEY Result.csv')
employee = pd.read_csv('../data/raw/Employee Data.csv')

# %%
competencies.head(10)
# Out:
#     #  Employee ID  Business Acumen  Interpersonal Sensitivity  \
# 0   1   Employee 1              3.0                        3.0
# 1   2   Employee 2              2.0                        2.0
# 2   3   Employee 3              3.0                        3.0
# 3   4   Employee 4              2.0                        2.0
# 4   5   Employee 5              2.0                        2.0
# 5   6   Employee 6              2.0                        2.0
# 6   7   Employee 7              2.0                        2.0
# 7   8   Employee 8              3.0                        3.0
# 8   9   Employee 9              2.0                        2.0
# 9  10  Employee 10              2.0                        2.0
#
#    Problem Solving and Decision Making  Comm Skills  Corporate Steward  \
# 0                                  3.0          3.0                3.0
# 1                                  2.0          2.0                2.0
# ...

# %%
sup.head(10)
# Out:
#     Employee ID Name of Assessor       Vertical:     Account  Business Acumen  \
# 0  Employee 328     Supervisor 2      Healthcare  Account 31                2
# 1  Employee 269     Supervisor 2      Healthcare  Account 31                2
# 2  Employee 385     Supervisor 2      Healthcare  Account 31                2
# 3  Employee 233     Supervisor 2      Healthcare  Account 31                2
# 4  Employee 160     Supervisor 2  Contact Center  Account 50                2
# 5  Employee 111     Supervisor 2      Healthcare  Account 31                3
# 6   Employee 65     Supervisor 2      Healthcare  Account 39                2
# 7   Employee 64     Supervisor 2      Healthcare  Account 31                2
# 8   Employee 59     Supervisor 2      Healthcare  Account 31                2
# 9   Employee 42     Supervisor 2  Contact Center  Account 24                2
#
#    Interpersonal Sensitivity Professional Ethics  \
# 0                          2                   3
# ...

# %%
auto.head(10)
# Out:
#     Employee ID  Business Acumen Interpersonal Sensitivity  \
# 0  Employee 289                2                         2
# 1  Employee 197                4                         3
# 2  Employee 318                2                         2
# 3  Employee 260                4                         3
# 4  Employee 217                2                         4
# 5  Employee 191                2                         2
# 6  Employee 395                1                         2
# 7   Employee 39                2                         2
# 8  Employee 292                2                         2
# 9  Employee 351                3                         3
#
#    Professional Ethics  Problem Solving and Decision Making  \
# 0                    2                                    2
# 1                    4                                    4
# 2                    2                                    3
# 3                    4                                    2
# ...

# %%
employee.head(10)
# Out:
#     #  Employee ID Employee Status   Hire Date  Job Grade Company        Level
# 0   1   Employee 1         Regular    9/1/2006          4  Makati       Leader
# 1   2   Employee 2         Regular   5/19/2008          2  Makati  Team Member
# 2   3   Employee 3         Regular   7/20/2009          3  Makati       Leader
# 3   4   Employee 4         Regular   9/19/2012          2  Makati  Team Member
# 4   5   Employee 5         Regular  10/17/2013          2  Makati  Team Member
# 5   6   Employee 6         Regular   4/16/2013          3  Makati       Leader
# 6   7   Employee 7         Regular    1/7/2013          3  Makati       Leader
# 7   8   Employee 8         Regular   12/2/2013          3  Makati       Leader
# 8   9   Employee 9         Regular   8/26/2014          2  Makati  Team Member
# 9  10  Employee 10         Regular   9/22/2014          2  Makati  Team Member

# %%
competencies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   #                                           671 non-null    int64
#  1   Employee ID                                 671 non-null    object
#  2   Business Acumen                             669 non-null    float64
#  3   Interpersonal Sensitivity                   669 non-null    float64
#  4   Problem Solving and Decision Making         669 non-null    float64
#  5   Comm Skills                                 669 non-null    float64
#  6   Corporate Steward                           669 non-null    float64
#  7   Relevant Professional Understanding         669 non-null    float64
#  8   Proficiency in the use of System and Tools  669 non-null    float64
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464 entries, 0 to 463
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Employee ID                                 464 non-null    object
#  1   Business Acumen                             464 non-null    int64
#  2   Interpersonal Sensitivity                   464 non-null    object
#  3   Professional Ethics                         464 non-null    int64
#  4   Problem Solving and Decision Making         464 non-null    int64
#  5   Communication Skills                        464 non-null    object
#  6   Corporate Steward                           464 non-null    int64
#  7   Relevant Professional Understanding         464 non-null    object
#  8   Computer Proficiency                        464 non-null    object
#  9   Proficiency in the use of System and Tools  464 non-null    object
# ...

# %%
sup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 655 entries, 0 to 654
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Employee ID                                 651 non-null    object
#  1   Name of Assessor                            649 non-null    object
#  2   Vertical:                                   649 non-null    object
#  3   Account                                     643 non-null    object
#  4   Business Acumen                             655 non-null    int64
#  5   Interpersonal Sensitivity                   655 non-null    int64
#  6   Professional Ethics                         458 non-null    object
#  7   Problem Solving and Decision Making         655 non-null    int64
#  8   Communication Skills                        655 non-null    int64
#  9   Corporate Steward                           655 non-null    int64
# ...

# %%
report_competencies = sv.DataframeReport(competencies)
report_superior = sv.DataframeReport(sup)
report_employee = sv.DataframeReport(auto)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)

# %%
report_competencies.show_html(filepath='../utils/competencies_report.html', 
            open_browser=False, 
            layout='widescreen', 
            scale=None)
report_superior.show_html(filepath='../utils/superior_report.html', 
            open_browser=False, 
            layout='widescreen', 
            scale=None)
report_employee.show_html(filepath='../utils/employee_report.html', 
            open_browser=False, 
            layout='widescreen', 
            scale=None)
# Out:
# Report ../utils/competencies_report.html was generated.
# Report ../utils/superior_report.html was generated.
# Report ../utils/employee_report.html was generated.

# %%
report_competencies.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %%
report_employee.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %%
report_superior.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# ### Conclusions after a first inspection (Regarding to data quality and general checks):
#
# 1. There are some missing values in all datasets but they are not a representative quantity in comparison to datasets size.
#
# 2. I can note that the datatypes in self-assessment there is a problematic register on several columns -> '#VALUES'. I'll change that for Nan an then I'll convert the datatypes to numeric.
#
# 3. Some datatypes on superior-assessment have to be changed from string to numeric.
#
# 4. There are more parameters on superior-assessment dataset than in desired-competencies dataset.
#
# 5. Desired-competencies has several records for the same employee. It happens with 6 employees. Since I don't have a parameter to know what set of assessments to use (Like a date, for example) I 'll just keep one register randomly.

# %%
# Making corrections

for column in auto.columns:
    auto[column] = auto[column].apply(lambda val: np.nan if val == '#VALUE!' else val)

for i in range(1,13):
    auto[auto.columns[i]] = auto[auto.columns[i]].astype('float')

for i in range(4,16):
    sup[sup.columns[i]] = sup[sup.columns[i]].astype('float')

competencies = competencies.drop_duplicates(subset=['Employee ID'])

# %%
# Checking if corrections were correctly applied
sv.DataframeReport(auto).show_notebook()
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# ## Generating the classification file

# %%
sup_filt = sup[sup.columns[4:]]
sup_filt['Employee ID'] = sup['Employee ID']
sup_filt = sup_filt.rename(columns={'Communication Skills': 'Comm Skills', 'People Development': 'People Devt'})
sup_filt = sup_filt.drop(columns=['Professional Ethics', 'Computer Proficiency'])
comp_filt = competencies.drop(columns=['#'])

result = pd.DataFrame(columns = sup_filt.columns)
result['Employee ID'] = sup_filt['Employee ID']


for employee in sup_filt['Employee ID']:
    if employee in comp_filt['Employee ID'].values:
        for column in comp_filt.columns:


            if sup_filt.loc[sup_filt['Employee ID'] == employee, [column]] > comp_filt.loc[comp_filt['Employee ID'] == employee, [column]]:
                result.loc[result['Employee ID'] == employee, [column]] == 'EXCEEDING'
# Out:
# <ipython-input-21-8092e4ae66e6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sup_filt['Employee ID'] = sup['Employee ID']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-8092e4ae66e6> in <module>
#      14
#      15
# ---> 16             if sup_filt.loc[sup_filt['Employee ID'] == employee, [column]] > comp_filt.loc[comp_filt['Employee ID'] == employee, [column]]:
#      17                 result.loc[result['Employee ID'] == employee, [column]] == 'EXCEEDING'
#      18
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in f(self, other)
#     836             # Another DataFrame
# ...

# %%
sup_filt.loc[sup_filt['Employee ID'] == 'Employee 328']
# Out:
#    Business Acumen  Interpersonal Sensitivity  \
# 0              2.0                        2.0
#
#    Problem Solving and Decision Making  Comm Skills  Corporate Steward  \
# 0                                  2.0          3.0                2.0
#
#    Relevant Professional Understanding  \
# 0                                  2.0
#
#    Proficiency in the use of System and Tools  Data Management  People Devt  \
# 0                                         3.0              2.0          2.0
#
#    Strategic Management   Employee ID
# 0                   2.0  Employee 328

# %%
'Employee 233' in sup_filt['Employee ID'].values
# Out:
# True

# %%
for employee in sup_filt['Employee ID']:
    c = comp_filt[comp_filt['Employee ID'] == employee]
    s = sup_filt[sup_filt['Employee ID'] == employee]

# %%
cols = ['Business Acumen', 'Interpersonal Sensitivity',
       'Problem Solving and Decision Making', 'Comm Skills',
       'Corporate Steward', 'Relevant Professional Understanding',
       'Proficiency in the use of System and Tools', 'Data Management',
       'People Devt', 'Strategic Management']
s_copy = s.copy()
for col in cols:
    r = s.apply(lambda row: row[col] > c[col], axis=1)
    # for i in range(len(s_copy)):
    #     if  'float' in str(type(s_copy[col].iloc[i])):
    #          s_copy[col].iloc[i] = np.where(s_copy[col].iloc[i] > c[col], s_copy[col].iloc[i], 'EXCEEDING')
    #          s_copy[col].iloc[i] = s_copy[col].iloc[i].flatten()

    # for i in range(len(s_copy)):
    #     if  'float' in str(type(s_copy[col].iloc[i])): 
    #         s_copy[col].iloc[i] = np.where(s_copy[col].iloc[i] < c[col], s_copy[col].iloc[i], 'BELOW EXPECTATIONS')
    #         s_copy[col].iloc[i] = s_copy[col].iloc[i].flatten()

    # for i in range(len(s_copy)):
    #     if  'float' in str(type(s_copy[col].iloc[i])):
    #         s_copy[col].iloc[i] = np.where(s_copy[col].iloc[i] == c[col], s_copy[col].iloc[i], 'EXHIBITING')
    #         s_copy[col].iloc[i] = s_copy[col].iloc[i].flatten()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-193-31ea61636ad5> in <module>
#       6 s_copy = s.copy()
#       7 for col in cols:
# ----> 8     r = s.apply(lambda row: row[col].mask(row[col] >= c[col], 'EXCEEDING', inplace=True))
#       9     # for i in range(len(s_copy)):
#      10     #     if  'float' in str(type(s_copy[col].iloc[i])):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ...

# %%
r.replace(True, 'EXCEEDING')
# Out:
#       192
# 338  hola
# 654  hola

# %%
mask_exceeding = s.iloc[0] > c
mask_below = s.iloc[0] < c
mask_exhibiting = s.iloc[0] == c
for col in cols:
    fila.loc[mask_exceeding, col] = 'EXCEEDING'

# %%
for col in fila.columns:
    if (mask_exceeding[col] == True):
        # 
        print('hola')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-217-2ac920a783f2> in <module>
#       1 for col in fila.columns.values:
# ----> 2     if (mask_exceeding[col] == True):
#       3         #
#       4         print('hola')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
mask_exceeding[col].value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-219-6944ace34d5f> in <module>
# ----> 1 mask_exceeding[col].value
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
fila.columns.values
# Out:
# array(['Business Acumen', 'Interpersonal Sensitivity',
#        'Problem Solving and Decision Making', 'Comm Skills',
#        'Corporate Steward', 'Relevant Professional Understanding',
#        'Proficiency in the use of System and Tools', 'Data Management',
#        'People Devt', 'Strategic Management', 'Employee ID'], dtype=object)

# %%
HACER ANALISIS POR VERTICAL (ESTA EN EL DF DE LOS SUPERIORES)
hacer analisis por cada uno de los supervisores
mirar donde cae en una distribucion la calificacion de un asesor y también hacerlo para empleado
hacer analisis por compañía y por nivel (eso está en el dataset de empleados)

# %%
fila = s.iloc[0].to_frame().T
